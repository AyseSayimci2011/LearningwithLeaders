# %% [markdown]
# <a href="https://colab.research.google.com/github/AyseSayimci2011/LearningwithLeaders/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
firstexam = input( 'Your first exam: ' )
secondexam = input( 'Your second exam:' )
thirdexam= input( 'Your third exam:' )
average= (float(firstexam)+ float(secondexam)+float(thirdexam))/3
print(average)
# Out:
# Your first exam: 6
# Your second exam:7
# Your third exam:7
# 6.666666666666667

# %%
num = int(input('number:'))

if num > 1:
   # logic
   for i in range (2, num):
    if (num % i) == 0:
      print(num, "is not a prime number")
      print(i, "times", num // i, "is", num)
      break
    else:
      print(num, "is a prime number")
else:
  print(num, 'is not a prime number')
# Out:
# number:8
# 8 is not a prime number
# 2 times 4 is 8

# %%
options = ['Rock', 'Paper', 'Scissors']
user_choice = input ('Choose Rock, Paper, Scissors')
computer_choice = random.choice(options)

user_choice = user choice, lower
print('You choses; ', user_choice)
print('Computer chose:' , computer_choice)

#winning/losing logic

if user_choice == computer_choice:
  print ('Its a tie!!')
elif user_choice == 'rock' and computer_choice == 'scissors':
  print('You win!!')
elif user_choice == 'paper' and computer_choice == 'rock':
  print('You win!!')
elif user_choice == 'scissors' and computer_choice == 'paper':
  print('You win!!')
  else:
    print('Computer wins!!')
# Out:
#   File "<ipython-input-15-788586197>", line 5
#     user_choice = user choice, lower
#                        ^
# SyntaxError: invalid syntax

# %%
     import cv2
     from google.colab.patches import cv2_imshow

     img = cv2.imread('kitty.jpeg')
     cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
from __future__ import print_function

import cv2 as cv

alpha = 0.5

try:
  raw_input              #python 2
except NameError:
  raw_input = input      #python 3
print('''Simple Linear Blender
-----------------------
* Enter alpha [0.0-1.0]: ''')

input_alpha = float(raw_input().strip())
if 0 <= alpha <= 1:
    alpha = input_alpha
# [load]
src1 = cv2.imread('kitty.jpeg')
src2 = cv2.imread('cookie.avif')

# choose dimesions
target_width = 300
target_height = 300
target_dimensions = (target_width, target_height)

# resize src1
src1 = cv2.resize(src1, target_dimensions)

# resize src2
src2 = cv2.resize(src2, target_dimensions)

# display image
cv2_imshow(blended)
# Out:
# Simple Linear Blender
# -----------------------
# * Enter alpha [0.0-1.0]:
# 0.5
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-19-3605592008> in <cell line: 0>()
#      29
#      30 # resize src2
# ---> 31 src2 = cv2.resize(src2, target_dimensions)
#      32
#      33 # display image
#
# error: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
# import libary
import cv2

# load in image
img = cv2.imread('kitty.jpeg' , cv2IMREAD_GRAYSCALE)

# apply gaussian blue to reduce noise
blurred_img = cv2.GuassianBlur(img,(5, 5), 0)

# apply canny edge detection
edges = cv2.Canny(blurred_img, 50, 150)
cv
